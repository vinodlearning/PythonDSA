# %%
import pandas as pd
import os as o
import matplotlib.pyplot as plt
o.getcwd()
# Out:
# 'f:\\GitHub_VinodLearning\\24Nov2024\\PythonDSA'

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_csv('data/disease.csv')
# Out:
#      age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1  3.0     145.0   233    1      NaN    150.0    0.0      2.3
# 1     37    1  2.0     130.0   250    0      NaN      NaN    NaN      NaN
# 2     41    0  1.0     130.0   204    0      NaN      NaN    NaN      NaN
# 3     56    1  1.0     120.0   236    0      NaN      NaN    NaN      NaN
# 4     57    0  0.0     120.0   354    0      NaN      NaN    NaN      NaN
# ..   ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 298   57    0  0.0     140.0   241    0      1.0    123.0    1.0      0.2
# 299   45    1  3.0     110.0   264    0      1.0    132.0    0.0      1.2
# 300   68    1  0.0     144.0   193    1      1.0    141.0    0.0      3.4
# 301   57    1  0.0     130.0   131    0      1.0    115.0    1.0      1.2
# 302   57    0  1.0     130.0   236    0      0.0    174.0    0.0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
pd.read_csv('data/weather.csv')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# Numpy deal with numbers...... but
# pandas deal with numbers along with strings

# %%
dataFrame=pd.read_csv('data/gapminder - gapminder.csv')
# table - we represents as data frames and series 
# vector we call matrix and vectors

# %%
dataFrame.head() # default value is 5
# Out:
#    Serial Number      country  year  population continent  life_exp  \
# 0             11  Afghanistan  2007    31889923      Asia    43.828
# 1             23      Albania  2007     3600523    Europe    76.423
# 2             35      Algeria  2007    33333216    Africa    72.301
# 3             47       Angola  2007    12420476    Africa    42.731
# 4             59    Argentina  2007    40301927  Americas    75.320
#
#         gdp_cap
# 0    974.580338
# 1   5937.029526
# 2   6223.367465
# 3   4797.231267
# 4  12779.379640

# %%
dataFrame.head(1)
# Out:
#    Serial Number      country  year  population continent  life_exp  \
# 0             11  Afghanistan  2007    31889923      Asia    43.828
#
#       gdp_cap
# 0  974.580338

# %%
type(dataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
dataFrame.info() # meta data about the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Serial Number  142 non-null    int64
#  1   country        142 non-null    object
#  2   year           142 non-null    int64
#  3   population     142 non-null    int64
#  4   continent      142 non-null    object
#  5   life_exp       142 non-null    float64
#  6   gdp_cap        142 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 7.9+ KB

# %%
dataFrame_xl=pd.read_excel("data/Indian_Prime_Miniters.xlsx")

dataFrame_xl
# Out:
#           Prime Minister           Political Party     Tenure    Age  \
# 0       Jawaharlal Nehru  Indian National Congress  1947-1964  58-75
# 1    Lal Bahadur Shastri  Indian National Congress  1964-1966  59-61
# 2          Indira Gandhi  Indian National Congress  1966-1977  48-59
# 3          Morarji Desai              Janata Party  1977-1979  81-83
# 4           Charan Singh              Janata Party  1979-1980  73-74
# 5          Indira Gandhi  Indian National Congress  1980-1984  63-67
# 6           Rajiv Gandhi  Indian National Congress  1984-1989  40-45
# 7             V.P. Singh                Janata Dal  1989-1990  57-58
# 8        Chandra Shekhar    Samajwadi Janata Party  1990-1991  63-64
# 9     P.V. Narasimha Rao  Indian National Congress  1991-1996  70-75
# 10  Atal Bihari Vajpayee    Bharatiya Janata Party       1996     71
# 11       H.D. Deve Gowda                Janata Dal  1996-1997  64-65
# 12           I.K. Gujral                Janata Dal  1997-1998  78-79
# ...

# %%
dataFrame_xl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 40 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Prime Minister                                                 16 non-null     object
#  1   Political Party                                                16 non-null     object
#  2   Tenure                                                         16 non-null     object
#  3   Age                                                            16 non-null     object
#  4   Lifespan                                                       16 non-null     object
#  5   State                                                          16 non-null     object
#  6   Educational Qualification                                      16 non-null     object
# ...

# %%
dataFrame_xl.describe() ## statical summary for numerical columns
# Out:
#        No. of Marriages  No. of Children  \
# count         16.000000        16.000000
# mean           1.125000         2.625000
# std            0.341565         1.707825
# min            1.000000         0.000000
# 25%            1.000000         1.750000
# 50%            1.000000         2.000000
# 75%            1.000000         4.000000
# max            2.000000         6.000000
#
#        GDP at Beginning of Tenure (in Rs. crores)  \
# count                                1.600000e+01
# mean                                 1.562116e+06
# std                                  2.659983e+06
# min                                  2.714000e+03
# 25%                                  6.029900e+04
# 50%                                  4.980575e+05
# 75%                                  2.050796e+06
# max                                  1.041146e+07
#
#        GDP at End of Tenure (in Rs. crores)  \
# count                          1.600000e+01
# ...

# %%
dataFrame.describe()
# Out:
#        Serial Number         year    population    life_exp       gdp_cap
# count     142.000000   142.000000  1.420000e+02  142.000000    142.000000
# mean      857.000000  2007.161972  4.402122e+07   67.007423  11680.071820
# std       493.631441     0.813340  1.476214e+08   12.073021  12859.937337
# min        11.000000  2003.000000  1.995790e+05   39.613000    277.551859
# 25%       434.000000  2007.000000  4.508034e+06   57.160250   1624.842248
# 50%       857.000000  2007.000000  1.051753e+07   71.935500   6124.371108
# 75%      1280.000000  2007.000000  3.121004e+07   76.413250  18008.835640
# max      1703.000000  2010.000000  1.318683e+09   82.603000  49357.190170

# %%
dataFrame.columns ## describe all the columns in excel/csv
# Out:
# Index(['Serial Number', 'country', 'year', 'population', 'continent',
#        'life_exp', 'gdp_cap'],
#       dtype='object')

# %%
dataFrame.keys()
# Out:
# Index(['Serial Number', 'country', 'year', 'population', 'continent',
#        'life_exp', 'gdp_cap'],
#       dtype='object')

# %%
dataFrame['country'].head()
# Out:
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3         Angola
# 4      Argentina
# Name: country, dtype: object

# %%
dataFrame[['country','continent']].head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3       Angola    Africa
# 4    Argentina  Americas

# %%
# DML - Data manipulate on Files

dataFrame.drop('continent',axis=1) ## won't delete the originla data frame
# Out:
#      Serial Number             country  year  population  life_exp  \
# 0               11         Afghanistan  2007    31889923    43.828
# 1               23             Albania  2007     3600523    76.423
# 2               35             Algeria  2007    33333216    72.301
# 3               47              Angola  2007    12420476    42.731
# 4               59           Argentina  2007    40301927    75.320
# ..             ...                 ...   ...         ...       ...
# 137           1655             Vietnam  2007    85262356    74.249
# 138           1667  West Bank and Gaza  2007     4018332    73.422
# 139           1679         Yemen, Rep.  2007    22211743    62.698
# 140           1691              Zambia  2007    11746035    42.384
# 141           1703            Zimbabwe  2007    12311143    43.487
#
#           gdp_cap
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# 3     4797.231267
# 4    12779.379640
# ..            ...
# 137   2441.576404
# ...

# %%
dataFrame.head()
# Out:
#    Serial Number      country  year  population continent  life_exp  \
# 0             11  Afghanistan  2007    31889923      Asia    43.828
# 1             23      Albania  2007     3600523    Europe    76.423
# 2             35      Algeria  2007    33333216    Africa    72.301
# 3             47       Angola  2007    12420476    Africa    42.731
# 4             59    Argentina  2007    40301927  Americas    75.320
#
#         gdp_cap
# 0    974.580338
# 1   5937.029526
# 2   6223.367465
# 3   4797.231267
# 4  12779.379640

# %%
# dataFrame.drop('continent', axis=1,inplace=True)
dataFrame.head()
# Out:
#    Serial Number      country  year  population continent  life_exp  \
# 0             11  Afghanistan  2007    31889923      Asia    43.828
# 1             23      Albania  2007     3600523    Europe    76.423
# 2             35      Algeria  2007    33333216    Africa    72.301
# 3             47       Angola  2007    12420476    Africa    42.731
# 4             59    Argentina  2007    40301927  Americas    75.320
#
#         gdp_cap
# 0    974.580338
# 1   5937.029526
# 2   6223.367465
# 3   4797.231267
# 4  12779.379640

# %%
# 
# if we want the original data back then read the file again (only option)

dataFrame=pd.read_csv("data/gapminder - gapminder.csv")
dataFrame
# Out:
#      Serial Number             country  year  population continent  life_exp  \
# 0               11         Afghanistan  2007    31889923      Asia    43.828
# 1               23             Albania  2007     3600523    Europe    76.423
# 2               35             Algeria  2007    33333216    Africa    72.301
# 3               47              Angola  2007    12420476    Africa    42.731
# 4               59           Argentina  2007    40301927  Americas    75.320
# ..             ...                 ...   ...         ...       ...       ...
# 137           1655             Vietnam  2007    85262356      Asia    74.249
# 138           1667  West Bank and Gaza  2007     4018332      Asia    73.422
# 139           1679         Yemen, Rep.  2007    22211743      Asia    62.698
# 140           1691              Zambia  2007    11746035    Africa    42.384
# 141           1703            Zimbabwe  2007    12311143    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# ...

# %% [markdown]
# **$$
# # LOC --> always works with label (indexes)
# # IlOC--> always works with actual indexes
# $$**

# %%
dataFrame.loc[3]
# Out:
# Serial Number             47
# country               Angola
# year                    2007
# population          12420476
# continent             Africa
# life_exp              42.731
# gdp_cap          4797.231267
# Name: 3, dtype: object

# %%
dataFrame.iloc[3]
# Out:
# Serial Number             47
# country               Angola
# year                    2007
# population          12420476
# continent             Africa
# life_exp              42.731
# gdp_cap          4797.231267
# Name: 3, dtype: object

# %%
dataFrame.iloc[[3,6,9]]
# Out:
#    Serial Number  country  year  population continent  life_exp       gdp_cap
# 3             47   Angola  2007    12420476    Africa    42.731   4797.231267
# 6             83  Austria  2007     8199783    Europe    79.829  36126.492700
# 9            119  Belgium  2010    10392226    Europe    79.441  33692.605080

# %%
dataFrame.iloc[-1]
# Out:
# Serial Number          1703
# country            Zimbabwe
# year                   2007
# population         12311143
# continent            Africa
# life_exp             43.487
# gdp_cap          469.709298
# Name: 141, dtype: object

# %%
dataFrame.loc[-1]

# bcz we don't have any lable with -1 so getting error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\vinod\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 dataFrame.loc[-1]
#       3 # bcz we don't have any lable with -1 so getting error
#
# File c:\Users\vinod\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
dataFrame.loc[3:5] # dealing with labels so 5 included
# Out:
#    Serial Number    country  year  population continent  life_exp  \
# 3             47     Angola  2007    12420476    Africa    42.731
# 4             59  Argentina  2007    40301927  Americas    75.320
# 5             71  Australia  2007    20434176   Oceania    81.235
#
#         gdp_cap
# 3   4797.231267
# 4  12779.379640
# 5  34435.367440

# %%
dataFrame.iloc[3:5] # dealing with indexes so 5 excluded
# Out:
#    Serial Number    country  year  population continent  life_exp  \
# 3             47     Angola  2007    12420476    Africa    42.731
# 4             59  Argentina  2007    40301927  Americas    75.320
#
#         gdp_cap
# 3   4797.231267
# 4  12779.379640

# %%
dataFrame.iloc[1:5,1:4]
# Out:
#      country  year  population
# 1    Albania  2007     3600523
# 2    Algeria  2007    33333216
# 3     Angola  2007    12420476
# 4  Argentina  2007    40301927

# %%
dataFrame.loc[1:5,1:4]

## loc deals with label so rows we  get the labels but coming to second param it deals with column so we dont have lable so getting error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dataFrame.loc[1:5,1:4]
#
# File c:\Users\vinod\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\vinod\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
dataFrame.loc[1:5,['continent','country']]
# Out:
#   continent    country
# 1    Europe    Albania
# 2    Africa    Algeria
# 3    Africa     Angola
# 4  Americas  Argentina
# 5   Oceania  Australia

# %%
dataFrame.loc[[1,3,6,9,11],['continent','country']]
# Out:
#    continent  country
# 1     Europe  Albania
# 3     Africa   Angola
# 6     Europe  Austria
# 9     Europe  Belgium
# 11  Americas  Bolivia

# %%
dataFrame.iloc[1:10:2]
# Out:
#    Serial Number    country  year  population continent  life_exp  \
# 1             23    Albania  2007     3600523    Europe    76.423
# 3             47     Angola  2007    12420476    Africa    42.731
# 5             71  Australia  2007    20434176   Oceania    81.235
# 7             95    Bahrain  2007      708573      Asia    75.635
# 9            119    Belgium  2007    10392226    Europe    79.441
#
#         gdp_cap
# 1   5937.029526
# 3   4797.231267
# 5  34435.367440
# 7  29796.048340
# 9  33692.605080

# %%
dataFrame.loc[1:5:3, "continent":"life_exp"]
# Out:
#   continent  life_exp
# 1    Europe    76.423
# 4  Americas    75.320

# %%
# delete the particular 

dataFrame.drop(2)
# dataFrame.drop(index=dataFrame.loc[2].index)
# Out:
#      Serial Number             country  year  population continent  life_exp  \
# 0               11         Afghanistan  2007    31889923      Asia    43.828
# 1               23             Albania  2007     3600523    Europe    76.423
# 3               47              Angola  2007    12420476    Africa    42.731
# 4               59           Argentina  2007    40301927  Americas    75.320
# 5               71           Australia  2007    20434176   Oceania    81.235
# ..             ...                 ...   ...         ...       ...       ...
# 137           1655             Vietnam  2007    85262356      Asia    74.249
# 138           1667  West Bank and Gaza  2007     4018332      Asia    73.422
# 139           1679         Yemen, Rep.  2007    22211743      Asia    62.698
# 140           1691              Zambia  2007    11746035    Africa    42.384
# 141           1703            Zimbabwe  2007    12311143    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# ...

# %% [markdown]
# # **###### Series**

# %%
r=dataFrame.loc[0] #row 
type(r)
# Out:
# pandas.core.series.Series

# %%
c=dataFrame['continent'] # column
type(c)
# Out:
# pandas.core.series.Series

# %%
le=dataFrame['life_exp']
le.mean()

int(le.mean())
# Out:
# 67

# %%
int(le.count())
# Out:
# 142

# %% [markdown]
# ###### both are same
# ######
# dataFrame.life_exp or dataFrame['life_exp']

# %%
dataFrame.life_exp>40
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 137    True
# 138    True
# 139    True
# 140    True
# 141    True
# Name: life_exp, Length: 142, dtype: bool

# %%
dataFrame.loc[dataFrame.life_exp>40]
# Out:
#      Serial Number             country  year  population continent  life_exp  \
# 0               11         Afghanistan  2007    31889923      Asia    43.828
# 1               23             Albania  2007     3600523    Europe    76.423
# 2               35             Algeria  2007    33333216    Africa    72.301
# 3               47              Angola  2007    12420476    Africa    42.731
# 4               59           Argentina  2007    40301927  Americas    75.320
# ..             ...                 ...   ...         ...       ...       ...
# 137           1655             Vietnam  2007    85262356      Asia    74.249
# 138           1667  West Bank and Gaza  2007     4018332      Asia    73.422
# 139           1679         Yemen, Rep.  2007    22211743      Asia    62.698
# 140           1691              Zambia  2007    11746035    Africa    42.384
# 141           1703            Zimbabwe  2007    12311143    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# ...

# %%
dataFrame.loc[dataFrame.life_exp>40].head()
# Out:
#    Serial Number      country  year  population continent  life_exp  \
# 0             11  Afghanistan  2007    31889923      Asia    43.828
# 1             23      Albania  2007     3600523    Europe    76.423
# 2             35      Algeria  2007    33333216    Africa    72.301
# 3             47       Angola  2007    12420476    Africa    42.731
# 4             59    Argentina  2007    40301927  Americas    75.320
#
#         gdp_cap
# 0    974.580338
# 1   5937.029526
# 2   6223.367465
# 3   4797.231267
# 4  12779.379640

# %%
dataFrame.loc[dataFrame.life_exp>40,['country','continent']].head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3       Angola    Africa
# 4    Argentina  Americas

# %%
filtered_data=dataFrame.loc[(dataFrame.life_exp>40) & (dataFrame.life_exp<60),['country','continent','life_exp']].head()

plt.figure(figsize=(8, 6))
# plt.pie(filtered_data['life_exp'], labels=filtered_data['country'], autopct='%1.1f%%', startangle=90)
plt.bar(filtered_data['country'], filtered_data['life_exp'], color='skyblue')
plt.title("Life Expectancy Greater than 40 (Pie Chart)")
plt.show()

# %%
dataFrame.loc[(dataFrame.country=='Kenya') | (dataFrame.country=='Egypt'),['country','continent']]
# Out:
#    country continent
# 38   Egypt    Africa
# 68   Kenya    Africa

# %%
dataFrame.groupby('year')[['life_exp','gdp_cap']].mean()
# Out:
#        life_exp       gdp_cap
# year
# 2003  50.430000   2042.095240
# 2007  67.062341  11716.833559
# 2010  68.043889  12211.785932

# %%
dataFrame.groupby(['continent','year'])[['life_exp','gdp_cap']].mean().head()
# Out:
#                  life_exp       gdp_cap
# continent year
# Africa    2003  50.430000   2042.095240
#           2007  54.939347   2950.540073
#           2010  53.728000   7005.568321
# Americas  2007  74.011261  11399.471858
#           2010  68.972000   6443.968955

# %%
dataFrame.groupby(['continent','year'])[['life_exp','gdp_cap']].mean()
# Out:
#                  life_exp       gdp_cap
# continent year
# Africa    2003  50.430000   2042.095240
#           2007  54.939347   2950.540073
#           2010  53.728000   7005.568321
# Americas  2007  74.011261  11399.471858
#           2010  68.972000   6443.968955
# Asia      2007  70.785258  12271.696277
#           2010  69.848500  15593.651066
# Europe    2007  77.857778  25919.064903
#           2010  75.766000  17273.232234
# Oceania   2007  80.719500  29810.188275

# %%
dataFrame.groupby(['continent','year'])[['life_exp','gdp_cap']].mean().reset_index()
# Out:
#   continent  year   life_exp       gdp_cap
# 0    Africa  2003  50.430000   2042.095240
# 1    Africa  2007  54.939347   2950.540073
# 2    Africa  2010  53.728000   7005.568321
# 3  Americas  2007  74.011261  11399.471858
# 4  Americas  2010  68.972000   6443.968955
# 5      Asia  2007  70.785258  12271.696277
# 6      Asia  2010  69.848500  15593.651066
# 7    Europe  2007  77.857778  25919.064903
# 8    Europe  2010  75.766000  17273.232234
# 9   Oceania  2007  80.719500  29810.188275

# %%
dataFrame.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
dataFrame.sort_values(['life_exp'])
# Out:
#      Serial Number           country  year  population continent  life_exp  \
# 121           1463         Swaziland  2007     1133066    Africa    39.613
# 86            1043        Mozambique  2007    19951656    Africa    42.082
# 140           1691            Zambia  2007    11746035    Africa    42.384
# 112           1355      Sierra Leone  2007     6144562    Africa    42.568
# 73             887           Lesotho  2007     2012649    Africa    42.592
# ..             ...               ...   ...         ...       ...       ...
# 5               71         Australia  2007    20434176   Oceania    81.235
# 123           1487       Switzerland  2007     7554661    Europe    81.701
# 57             695           Iceland  2007      301931    Europe    81.757
# 55             671  Hong Kong, China  2007     6980412      Asia    82.208
# 66             803             Japan  2007   127467972      Asia    82.603
#
#           gdp_cap
# 121   4513.480643
# 86     823.685621
# ...

# %%
dataFrame.sort_values(['year'], ascending=False).tail()
# Out:
#      Serial Number      country  year  population continent  life_exp  \
# 137           1655      Vietnam  2007    85262356      Asia    74.249
# 140           1691       Zambia  2007    11746035    Africa    42.384
# 139           1679  Yemen, Rep.  2007    22211743      Asia    62.698
# 141           1703     Zimbabwe  2007    12311143    Africa    43.487
# 19             239     Cameroon  2003    17696293    Africa    50.430
#
#          gdp_cap
# 137  2441.576404
# 140  1271.211593
# 139  2280.769906
# 141   469.709298
# 19   2042.095240

# %%
dataFrame.sort_values(['year'], ascending=False).head()
# Out:
#     Serial Number                 country  year  population continent  \
# 11            143                 Bolivia  2010     9119152  Americas
# 12            155  Bosnia and Herzegovina  2010     4552198    Europe
# 10            131                   Benin  2010     8078314    Africa
# 9             119                 Belgium  2010    10392226    Europe
# 8             107              Bangladesh  2010   150448339      Asia
#
#     life_exp       gdp_cap
# 11    65.554   3822.137084
# 12    74.852   7446.298803
# 10    56.728   1441.284873
# 9     79.441  33692.605080
# 8     64.062   1391.253792

# %%
pd.Series([10,20,30,40,50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
dataFrame.life_exp #dataFrame['life_exp']
# Out:
# 0      43.828
# 1      76.423
# 2      72.301
# 3      42.731
# 4      75.320
#         ...
# 137    74.249
# 138    73.422
# 139    62.698
# 140    42.384
# 141    43.487
# Name: life_exp, Length: 142, dtype: float64

# %%
pd.DataFrame([[10,20],[140,50]],columns=['A','B']) ## it represents the row 

# list of rows [ [ ]] expect these
# Out:
#      A   B
# 0   10  20
# 1  140  50

# %%
lst=list()
for i in range(5):
    lst.append(i)



pd.DataFrame({'A':[1,2,3,4,5],
              'Name' : ["vinod","Krish","vinod","Krish","Test"]
              
              })
# Out:
#    A   Name
# 0  1  vinod
# 1  2  Krish
# 2  3  vinod
# 3  4  Krish
# 4  5   Test

# %%
lst=list()
for i in range(5):
    lst.append(i)

lst1=list()
for i in range(5):
    lst1.append(f"Vinod {i}")

a=pd.DataFrame({'A':[1,2,3,4,5],
              'Name' : lst
              
              })
b=pd.DataFrame({'A':[1,2,3,4,5],
              'C' : lst1
              
              })

a
b
# Out:
#    A        C
# 0  1  Vinod 0
# 1  2  Vinod 1
# 2  3  Vinod 2
# 3  4  Vinod 3
# 4  5  Vinod 4

# %%
pd.concat([a,b]) ## vertical addition
# Out:
#    A  Name        C
# 0  1   0.0      NaN
# 1  2   1.0      NaN
# 2  3   2.0      NaN
# 3  4   3.0      NaN
# 4  5   4.0      NaN
# 0  1   NaN  Vinod 0
# 1  2   NaN  Vinod 1
# 2  3   NaN  Vinod 2
# 3  4   NaN  Vinod 3
# 4  5   NaN  Vinod 4

# %%
pd.concat([a,b],axis=1) ## provide axis horizontal concatination
# Out:
#    A  Name  A        C
# 0  1     0  1  Vinod 0
# 1  2     1  2  Vinod 1
# 2  3     2  3  Vinod 2
# 3  4     3  4  Vinod 3
# 4  5     4  5  Vinod 4

# %%
pd.concat([a,b],axis=0) ## default value axis is zero --> vertical concatination
# Out:
#    A  Name        C
# 0  1   0.0      NaN
# 1  2   1.0      NaN
# 2  3   2.0      NaN
# 3  4   3.0      NaN
# 4  5   4.0      NaN
# 0  1   NaN  Vinod 0
# 1  2   NaN  Vinod 1
# 2  3   NaN  Vinod 2
# 3  4   NaN  Vinod 3
# 4  5   NaN  Vinod 4

# %%
disease=pd.read_csv("data/disease.csv") 
# csv- comma separated value
# tsv - tab  separated value
pd.reset_option('display.max_rows') 
disease
# Out:
#      age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1  3.0     145.0   233    1      NaN    150.0    0.0      2.3
# 1     37    1  2.0     130.0   250    0      NaN      NaN    NaN      NaN
# 2     41    0  1.0     130.0   204    0      NaN      NaN    NaN      NaN
# 3     56    1  1.0     120.0   236    0      NaN      NaN    NaN      NaN
# 4     57    0  0.0     120.0   354    0      NaN      NaN    NaN      NaN
# ..   ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 298   57    0  0.0     140.0   241    0      1.0    123.0    1.0      0.2
# 299   45    1  3.0     110.0   264    0      1.0    132.0    0.0      1.2
# 300   68    1  0.0     144.0   193    1      1.0    141.0    0.0      3.4
# 301   57    1  0.0     130.0   131    0      1.0    115.0    1.0      1.2
# 302   57    0  1.0     130.0   236    0      0.0    174.0    0.0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
# finding missing values

disease.dropna()
# Out:
#      age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 21    44    1  2.0     130.0   233    0      1.0    179.0    1.0      0.4
# 22    42    1  0.0     140.0   226    0      1.0    178.0    0.0      0.0
# 23    61    1  2.0     150.0   243    1      1.0    137.0    1.0      1.0
# 24    40    1  3.0     140.0   199    0      1.0    178.0    1.0      1.4
# 25    71    0  1.0     160.0   302    0      1.0    162.0    0.0      0.4
# ..   ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 298   57    0  0.0     140.0   241    0      1.0    123.0    1.0      0.2
# 299   45    1  3.0     110.0   264    0      1.0    132.0    0.0      1.2
# 300   68    1  0.0     144.0   193    1      1.0    141.0    0.0      3.4
# 301   57    1  0.0     130.0   131    0      1.0    115.0    1.0      1.2
# 302   57    0  1.0     130.0   236    0      0.0    174.0    0.0      0.0
#
#      slope  ca  thal  target
# 21       2   0     2       1
# ...

# %%
disease
# Out:
#      age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1  3.0     145.0   233    1      NaN    150.0    0.0      2.3
# 1     37    1  2.0     130.0   250    0      NaN      NaN    NaN      NaN
# 2     41    0  1.0     130.0   204    0      NaN      NaN    NaN      NaN
# 3     56    1  1.0     120.0   236    0      NaN      NaN    NaN      NaN
# 4     57    0  0.0     120.0   354    0      NaN      NaN    NaN      NaN
# ..   ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 298   57    0  0.0     140.0   241    0      1.0    123.0    1.0      0.2
# 299   45    1  3.0     110.0   264    0      1.0    132.0    0.0      1.2
# 300   68    1  0.0     144.0   193    1      1.0    141.0    0.0      3.4
# 301   57    1  0.0     130.0   131    0      1.0    115.0    1.0      1.2
# 302   57    0  1.0     130.0   236    0      0.0    174.0    0.0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
import numpy as np

# %%
# %pip install numpy --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.6 MB 9.7 MB/s eta 0:00:02
#    ------------------------------- -------- 10.0/12.6 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 29.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\vinod\AppData\Local\Programs\Python\Python313\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\vinod\AppData\Local\Programs\Python\Python313\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
np.nan==np.nan
# Out:
# False

# %%
np.nan is np.nan
# Out:
# True

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        291 non-null    float64
#  3   trestbps  291 non-null    float64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   292 non-null    float64
#  7   thalach   288 non-null    float64
#  8   exang     288 non-null    float64
#  9   oldpeak   288 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(6), int64(8)
# memory usage: 33.3 KB

# %%
disease['age'].value_counts()
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 44    11
# 56    11
# 60    11
# 64    10
# 41    10
# 63     9
# 67     9
# 65     8
# 53     8
# 61     8
# 45     8
# 43     8
# 42     8
# 55     8
# 66     7
# 48     7
# 50     7
# 46     7
# 49     5
# 47     5
# 68     4
# 39     4
# 35     4
# 70     4
# 40     3
# 69     3
# 38     3
# 71     3
# 37     2
# 34     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: count, dtype: int64

# %%
disease.head()
# Out:
#    age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    1  3.0     145.0   233    1      NaN    150.0    0.0      2.3
# 1   37    1  2.0     130.0   250    0      NaN      NaN    NaN      NaN
# 2   41    0  1.0     130.0   204    0      NaN      NaN    NaN      NaN
# 3   56    1  1.0     120.0   236    0      NaN      NaN    NaN      NaN
# 4   57    0  0.0     120.0   354    0      NaN      NaN    NaN      NaN
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
disease['chol'].value_counts()
# Out:
# chol
# 204    6
# 234    6
# 197    6
# 212    5
# 269    5
#       ..
# 169    1
# 187    1
# 176    1
# 241    1
# 131    1
# Name: count, Length: 152, dtype: int64

# %%
d=disease['chol'].unique()
int(sum(d))
# Out:
# 38162

# %%
dataFrame.head()
# Out:
#    Serial Number      country  year  population continent  life_exp  \
# 0             11  Afghanistan  2007    31889923      Asia    43.828
# 1             23      Albania  2007     3600523    Europe    76.423
# 2             35      Algeria  2007    33333216    Africa    72.301
# 3             47       Angola  2007    12420476    Africa    42.731
# 4             59    Argentina  2007    40301927  Americas    75.320
#
#         gdp_cap
# 0    974.580338
# 1   5937.029526
# 2   6223.367465
# 3   4797.231267
# 4  12779.379640

# %%
disease.fillna(method='ffill')
# Out:
# C:\Users\vinod\AppData\Local\Temp\ipykernel_17096\1056305435.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   disease.fillna(method='ffill')
#      age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1  3.0     145.0   233    1      NaN    150.0    0.0      2.3
# 1     37    1  2.0     130.0   250    0      NaN    150.0    0.0      2.3
# 2     41    0  1.0     130.0   204    0      NaN    150.0    0.0      2.3
# 3     56    1  1.0     120.0   236    0      NaN    150.0    0.0      2.3
# 4     57    0  0.0     120.0   354    0      NaN    150.0    0.0      2.3
# ..   ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 298   57    0  0.0     140.0   241    0      1.0    123.0    1.0      0.2
# 299   45    1  3.0     110.0   264    0      1.0    132.0    0.0      1.2
# ...

# %%
disease.fillna(method='bfill')
# Out:
# C:\Users\vinod\AppData\Local\Temp\ipykernel_17096\3326842748.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   disease.fillna(method='bfill')
#      age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1  3.0     145.0   233    1      1.0    150.0    0.0      2.3
# 1     37    1  2.0     130.0   250    0      1.0    172.0    0.0      0.0
# 2     41    0  1.0     130.0   204    0      1.0    172.0    0.0      0.0
# 3     56    1  1.0     120.0   236    0      1.0    172.0    0.0      0.0
# 4     57    0  0.0     120.0   354    0      1.0    172.0    0.0      0.0
# ..   ...  ...  ...       ...   ...  ...      ...      ...    ...      ...
# 298   57    0  0.0     140.0   241    0      1.0    123.0    1.0      0.2
# 299   45    1  3.0     110.0   264    0      1.0    132.0    0.0      1.2
# ...
